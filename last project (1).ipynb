# %% [markdown]
# Project Title------>DeepCSAT – Ecommerce Customer Satisfaction Score Prediction
# -------------------------------------------------------------------------------
#
# Project Summary----->>
# ======================
#                       The project DeepCSAT focuses on predicting customer satisfaction scores in the e-commerce domain using advanced data analytics and deep learning techniques. In today’s highly competitive online marketplace, understanding customer sentiment and predicting satisfaction levels are crucial for improving service quality, customer retention, and business growth.
#
# The objective of this project is to develop a predictive model that can estimate a customer’s satisfaction score based on various factors such as order experience, delivery time, product quality, pricing, customer support, and feedback text. The project utilizes a deep learning approach, integrating natural language processing (NLP) for text-based reviews and numerical data analysis for structured features.
#
# The workflow includes data collection, preprocessing, and feature extraction, followed by model training using neural network architectures like Deep Neural Networks (DNNs) or Recurrent Neural Networks (RNNs). The model’s performance is evaluated using key metrics such as Mean Squared Error (MSE) and R² score to ensure high predictive accuracy.
#
# The outcome of DeepCSAT is a system capable of automatically predicting satisfaction levels and identifying potential problem areas, enabling e-commerce companies to make data-driven decisions to enhance the overall customer experience.
#
#
# Key Highlights====>
# -------------------
#
# >Domain: E-commerce & Customer Analytics
#
# >Tech Stack: Python, TensorFlow/Keras, Scikit-learn, Pandas, NLP (TextBlob or BERT)
#
# >Model Used: Deep Learning (DNN/RNN)
#
# >Goal: Predict customer satisfaction score accurately
#
# >Impact: Improved customer retention, service quality, and business insights
#
# 🎯 Project Goal----->
# ----------------------
#
# The primary goal of the DeepCSAT project is to predict customer satisfaction scores in the e-commerce sector using Artificial Neural Networks (ANNs) and data-driven insights.
#
#                    This project aims to develop an intelligent predictive system that can automatically estimate how satisfied a customer is likely to be based on various factors such as:
#
#   >Product quality and pricing
#
#   >Delivery performance
#
#   >Customer support interaction
#
#   >User feedback and review sentiment
#
#   >Overall shopping experience
#
# By accurately predicting the Customer Satisfaction (CSAT) Score, the model helps e-commerce platforms:
#
#   >Identify dissatisfied customers early
#
#   >Understand key pain points affecting satisfaction
#
#   >Improve decision-making in product quality, logistics, and service
#
#   >Enhance customer retention and build long-term loyalty

# %%
#import used libraries
# deepcsat_full_pipeline.py
# Run as a notebook or script. It inspects the CSV, trains baseline XGBoost and a Keras multimodal model.

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import joblib
from datetime import datetime
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ML libraries
import xgboost as xgb
import shap

# Deep learning
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers

# %%
#import the raw data
df=pd.read_csv('c:/labmentix/5th project/eCommerce_Customer_support_data.csv')
df
# Out:
#                                   Unique id channel_name         category  \
# 0      7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1      b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2      200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3      eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4      ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
# ...                                     ...          ...              ...
# 85902  505ea5e7-c475-4fac-ac36-1d19a4cb610f      Inbound   Refund Related
# 85903  44b38d3f-1523-4182-aba2-72917586647c      Inbound    Order Related
# 85904  723bce2c-496c-4aa8-a64b-ca17004528f0      Inbound    Order Related
# 85905  707528ee-6873-4192-bfa9-a491f1c08ab5      Inbound         Feedback
# 85906  07c7a878-0d5a-42e0-97ef-de59abec0238      Inbound          Returns
#
#                        Sub-category                          Customer Remarks  \
# 0                    Life Insurance                                       NaN
# 1      Product Specific Information                                       NaN
# 2                 Installation/demo                                       NaN
# 3            Reverse Pickup Enquiry                                       NaN
# 4                        Not Needed                                       NaN
# ...                             ...                                       ...
# 85902                Refund Enquiry                                       NaN
# 85903        Seller Cancelled Order  Supported team customer executive   good
# 85904          Order status enquiry      need to improve with proper details.
# 85905      UnProfessional Behaviour                                       NaN
# 85906        Reverse Pickup Enquiry                                       NaN
#
#                                    Order_id order_date_time Issue_reported at  \
# 0      c27c9bb4-fa36-4140-9f1f-21009254ffdb             NaN    1/8/2023 11:13
# 1      d406b0c7-ce17-4654-b9de-f08d421254bd             NaN    1/8/2023 12:52
# 2      c273368d-b961-44cb-beaf-62d6fd6c00d5             NaN    1/8/2023 20:16
# 3      5aed0059-55a4-4ec6-bb54-97942092020a             NaN    1/8/2023 20:56
# 4      e8bed5a9-6933-4aff-9dc6-ccefd7dcde59             NaN    1/8/2023 10:30
# ...                                     ...             ...               ...
# 85902  1b5a2b9c-a95f-405f-a42e-5b1b693f3dc9             NaN  30/08/2023 23:20
# 85903  d0e8a817-96d5-4ace-bb82-adec50398e22             NaN  31/08/2023 08:15
# 85904  bdefe788-ccec-4eda-8ca4-51045e68db8a             NaN  31/08/2023 18:57
# 85905  a031ec28-0c5e-450e-95b2-592342c40bc4             NaN  31/08/2023 19:59
# 85906  3230db30-f8da-4c44-8636-ec76d1d3d4f3             NaN  31/08/2023 23:36
#
#         issue_responded Survey_response_Date Customer_City Product_category  \
# 0        1/8/2023 11:47             1-Aug-23           NaN              NaN
# 1        1/8/2023 12:54             1-Aug-23           NaN              NaN
# 2        1/8/2023 20:38             1-Aug-23           NaN              NaN
# 3        1/8/2023 21:16             1-Aug-23           NaN              NaN
# 4        1/8/2023 10:32             1-Aug-23           NaN              NaN
# ...                 ...                  ...           ...              ...
# 85902  31/08/2023 07:22            31-Aug-23           NaN              NaN
# 85903  31/08/2023 08:17            31-Aug-23           NaN              NaN
# 85904  31/08/2023 19:02            31-Aug-23           NaN              NaN
# 85905  31/08/2023 20:00            31-Aug-23           NaN              NaN
# 85906  31/08/2023 23:37            31-Aug-23           NaN              NaN
#
#        Item_price  connected_handling_time           Agent_name  \
# 0             NaN                      NaN     Richard Buchanan
# 1             NaN                      NaN        Vicki Collins
# 2             NaN                      NaN         Duane Norman
# 3             NaN                      NaN       Patrick Flores
# 4             NaN                      NaN  Christopher Sanchez
# ...           ...                      ...                  ...
# 85902         NaN                      NaN         Brandon Leon
# 85903         NaN                      NaN         Linda Foster
# 85904         NaN                      NaN    Kimberly Martinez
# 85905         NaN                      NaN        Daniel Martin
# 85906         NaN                      NaN     Elizabeth Guerra
#
#            Supervisor          Manager    Tenure Bucket Agent Shift  \
# 0         Mason Gupta  Jennifer Nguyen  On Job Training     Morning
# 1           Dylan Kim      Michael Lee              >90     Morning
# 2        Jackson Park      William Kim  On Job Training     Evening
# 3         Olivia Wang       John Smith              >90     Evening
# 4      Austin Johnson      Michael Lee             0-30     Morning
# ...               ...              ...              ...         ...
# 85902       Ethan Tan      William Kim  On Job Training     Morning
# 85903      Noah Patel       Emily Chen              >90     Morning
# 85904     Aiden Patel       Olivia Tan  On Job Training     Evening
# 85905   Olivia Suzuki       Olivia Tan              >90     Morning
# 85906    Nathan Patel  Jennifer Nguyen  On Job Training     Evening
#
#        CSAT Score
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5
# ...           ...
# 85902           4
# 85903           5
# 85904           5
# 85905           4
# 85906           5
#
# [85907 rows x 20 columns]

# %%
#use command for checking the datatypes of the columns
df.dtypes
# Out:
# Unique id                   object
# channel_name                object
# category                    object
# Sub-category                object
# Customer Remarks            object
# Order_id                    object
# order_date_time             object
# Issue_reported at           object
# issue_responded             object
# Survey_response_Date        object
# Customer_City               object
# Product_category            object
# Item_price                 float64
# connected_handling_time    float64
# Agent_name                  object
# Supervisor                  object
# Manager                     object
# Tenure Bucket               object
# Agent Shift                 object
# CSAT Score                   int64
# dtype: object

# %%
#calculate total null values in the raw data
df.isnull().sum()
# Out:
# Unique id                      0
# channel_name                   0
# category                       0
# Sub-category                   0
# Customer Remarks           57165
# Order_id                   18232
# order_date_time            68693
# Issue_reported at              0
# issue_responded                0
# Survey_response_Date           0
# Customer_City              68828
# Product_category           68711
# Item_price                 68701
# connected_handling_time    85665
# Agent_name                     0
# Supervisor                     0
# Manager                        0
# Tenure Bucket                  0
# Agent Shift                    0
# CSAT Score                     0
# dtype: int64

# %%
#drop all duplicates values present in the raw data
df=df.drop_duplicates()
df
# Out:
#                                   Unique id channel_name         category  \
# 0      7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1      b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2      200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3      eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4      ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
# ...                                     ...          ...              ...
# 85902  505ea5e7-c475-4fac-ac36-1d19a4cb610f      Inbound   Refund Related
# 85903  44b38d3f-1523-4182-aba2-72917586647c      Inbound    Order Related
# 85904  723bce2c-496c-4aa8-a64b-ca17004528f0      Inbound    Order Related
# 85905  707528ee-6873-4192-bfa9-a491f1c08ab5      Inbound         Feedback
# 85906  07c7a878-0d5a-42e0-97ef-de59abec0238      Inbound          Returns
#
#                        Sub-category                          Customer Remarks  \
# 0                    Life Insurance                                       NaN
# 1      Product Specific Information                                       NaN
# 2                 Installation/demo                                       NaN
# 3            Reverse Pickup Enquiry                                       NaN
# 4                        Not Needed                                       NaN
# ...                             ...                                       ...
# 85902                Refund Enquiry                                       NaN
# 85903        Seller Cancelled Order  Supported team customer executive   good
# 85904          Order status enquiry      need to improve with proper details.
# 85905      UnProfessional Behaviour                                       NaN
# 85906        Reverse Pickup Enquiry                                       NaN
#
#                                    Order_id order_date_time Issue_reported at  \
# 0      c27c9bb4-fa36-4140-9f1f-21009254ffdb             NaN    1/8/2023 11:13
# 1      d406b0c7-ce17-4654-b9de-f08d421254bd             NaN    1/8/2023 12:52
# 2      c273368d-b961-44cb-beaf-62d6fd6c00d5             NaN    1/8/2023 20:16
# 3      5aed0059-55a4-4ec6-bb54-97942092020a             NaN    1/8/2023 20:56
# 4      e8bed5a9-6933-4aff-9dc6-ccefd7dcde59             NaN    1/8/2023 10:30
# ...                                     ...             ...               ...
# 85902  1b5a2b9c-a95f-405f-a42e-5b1b693f3dc9             NaN  30/08/2023 23:20
# 85903  d0e8a817-96d5-4ace-bb82-adec50398e22             NaN  31/08/2023 08:15
# 85904  bdefe788-ccec-4eda-8ca4-51045e68db8a             NaN  31/08/2023 18:57
# 85905  a031ec28-0c5e-450e-95b2-592342c40bc4             NaN  31/08/2023 19:59
# 85906  3230db30-f8da-4c44-8636-ec76d1d3d4f3             NaN  31/08/2023 23:36
#
#         issue_responded Survey_response_Date Customer_City Product_category  \
# 0        1/8/2023 11:47             1-Aug-23           NaN              NaN
# 1        1/8/2023 12:54             1-Aug-23           NaN              NaN
# 2        1/8/2023 20:38             1-Aug-23           NaN              NaN
# 3        1/8/2023 21:16             1-Aug-23           NaN              NaN
# 4        1/8/2023 10:32             1-Aug-23           NaN              NaN
# ...                 ...                  ...           ...              ...
# 85902  31/08/2023 07:22            31-Aug-23           NaN              NaN
# 85903  31/08/2023 08:17            31-Aug-23           NaN              NaN
# 85904  31/08/2023 19:02            31-Aug-23           NaN              NaN
# 85905  31/08/2023 20:00            31-Aug-23           NaN              NaN
# 85906  31/08/2023 23:37            31-Aug-23           NaN              NaN
#
#        Item_price  connected_handling_time           Agent_name  \
# 0             NaN                      NaN     Richard Buchanan
# 1             NaN                      NaN        Vicki Collins
# 2             NaN                      NaN         Duane Norman
# 3             NaN                      NaN       Patrick Flores
# 4             NaN                      NaN  Christopher Sanchez
# ...           ...                      ...                  ...
# 85902         NaN                      NaN         Brandon Leon
# 85903         NaN                      NaN         Linda Foster
# 85904         NaN                      NaN    Kimberly Martinez
# 85905         NaN                      NaN        Daniel Martin
# 85906         NaN                      NaN     Elizabeth Guerra
#
#            Supervisor          Manager    Tenure Bucket Agent Shift  \
# 0         Mason Gupta  Jennifer Nguyen  On Job Training     Morning
# 1           Dylan Kim      Michael Lee              >90     Morning
# 2        Jackson Park      William Kim  On Job Training     Evening
# 3         Olivia Wang       John Smith              >90     Evening
# 4      Austin Johnson      Michael Lee             0-30     Morning
# ...               ...              ...              ...         ...
# 85902       Ethan Tan      William Kim  On Job Training     Morning
# 85903      Noah Patel       Emily Chen              >90     Morning
# 85904     Aiden Patel       Olivia Tan  On Job Training     Evening
# 85905   Olivia Suzuki       Olivia Tan              >90     Morning
# 85906    Nathan Patel  Jennifer Nguyen  On Job Training     Evening
#
#        CSAT Score
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5
# ...           ...
# 85902           4
# 85903           5
# 85904           5
# 85905           4
# 85906           5
#
# [85907 rows x 20 columns]

# %%
#drop all null values from raw data
df=df.dropna()
df
# Out:
#                                   Unique id channel_name       category  \
# 13565  08c6a929-a403-4f14-810f-2275fe591230      Outcall        Returns
# 13603  eae37bb3-91ec-4154-ba3c-7e4a6309a946      Outcall        Returns
# 18445  296c5c93-6a4f-4fa5-b276-3feecfeaf636      Outcall        Returns
# 19678  5155d369-7bc3-4c40-9e26-6dcee58ace99      Outcall        Returns
# 20080  ddaae943-3535-452e-857f-591d4b9ae0c8      Outcall   Cancellation
# 20363  00c52c83-d40a-4b0f-80ea-fcffe23cef76      Outcall        Returns
# 20439  5b3a9dfe-8c26-4c5f-9824-02db5daf7ecb      Outcall        Returns
# 22514  8d093faf-8359-494d-9955-224cf8a5de8d      Outcall        Returns
# 26301  150a36e8-48bc-47d2-bce6-436b65d2fab8      Outcall        Returns
# 26387  1c0c98aa-2fdc-4899-af96-de7cbec1977c      Outcall        Returns
# 26499  43efcc9f-7143-4895-8ffe-e50421ee8b00      Outcall        Returns
# 26661  891fd7e5-59a5-43f9-9b1c-cf9b2e14b14e      Outcall        Returns
# 26708  82d615a4-6731-4a79-84b7-2bdb42e2c4dc      Outcall        Returns
# 27104  821583b1-48d9-40bb-849c-a32b0382d1fc      Outcall        Returns
# 27141  b4c7ceea-92d5-4f75-81aa-4e0a129ee638      Outcall        Returns
# 28193  22df64f7-2530-46e1-ba58-fee4265802f5      Outcall        Returns
# 28808  bc34a27a-bf19-4132-9629-88b09a9b6e2a      Outcall        Returns
# 28920  75bc0360-b5c6-4566-9880-24d5681f2de6      Outcall        Returns
# 29365  07030f1f-84c9-493c-a8a3-159f6d58ebc9      Outcall   Cancellation
# 31681  f5b74aa2-934d-4d44-a9aa-db68f42fc1c3      Outcall        Returns
# 31697  b9d109b9-35fa-40b2-a358-8ef83ac47bda      Outcall   Cancellation
# 33336  abf385db-925e-44c5-8112-a4399b61716c      Outcall        Returns
# 34544  7f55a2c1-9e16-4dd4-aa1c-8c28b40e02e0      Outcall   Cancellation
# 37420  28c46a62-2be4-401b-b73c-2c68486dd5cc      Outcall        Returns
# 37501  ee67e456-4cc1-40a4-9253-d1ecca814030      Outcall        Returns
# 37808  27c2659e-df10-4bac-af87-da3fae75a8b2      Outcall        Returns
# 38925  f5b9f8d9-05d1-4e67-b5dd-01b37b0a71b6      Outcall        Returns
# 39732  473de3fb-934b-4dd4-8f9d-91559ce291a8      Outcall        Returns
# 46703  ce3a498d-727a-4378-9b2f-519fb1e85c12      Outcall        Returns
# 46972  98105df6-15f2-4e73-a593-38138e4fdee4      Outcall        Returns
# 47532  66b067d8-cbb0-4d92-ad94-9b9fc760e269      Outcall        Returns
# 47745  89b8ba13-fa38-4ed9-8c67-b0ee610cac30      Outcall        Returns
# 48034  7905b6ac-e5c0-45e5-a71c-989d6050ceef      Outcall        Returns
# 48313  94e83ff7-d920-4b6c-a590-afadb71f85e4      Outcall        Returns
# 48710  f9af8085-e991-4205-8804-caefe6194040      Outcall        Returns
# 49018  b6501670-1fcc-49cb-8ab6-95fd411fc851      Outcall        Returns
# 55265  d1a52873-389a-4ad3-8043-7480181bda2a      Outcall        Returns
# 85016  2adb7651-c900-43b9-a539-d8f1d64df3c5      Inbound  Order Related
#
#                Sub-category  \
# 13565        Return request
# 13603        Return request
# 18445        Return request
# 19678        Return request
# 20080   Return cancellation
# 20363        Return request
# 20439        Return request
# 22514        Return request
# 26301        Return request
# 26387        Return request
# 26499        Return request
# 26661        Return request
# 26708        Return request
# 27104        Return request
# 27141        Return request
# 28193        Return request
# 28808        Return request
# 28920        Return request
# 29365   Return cancellation
# 31681        Return request
# 31697   Return cancellation
# 33336        Return request
# 34544   Return cancellation
# 37420        Return request
# 37501        Return request
# 37808        Return request
# 38925        Return request
# 39732        Return request
# 46703        Return request
# 46972        Return request
# 47532        Return request
# 47745        Return request
# 48034        Return request
# 48313        Return request
# 48710        Return request
# 49018        Return request
# 55265        Return request
# 85016  Order status enquiry
#
#                                         Customer Remarks  \
# 13565                                               Good
# 13603                                          Not good
# 18445                                  Call was helpful.
# 19678                                       Good service
# 20080                                            Thanks
# 20363                                           Good job
# 20439                                Super customer care
# 22514                         Very genuine person ??????
# 26301  Product is not best.delivery good.costmor care...
# 26387                              Shopzilla Is the Best
# 26499                                               Good
# 26661                                          Thankyou
# 26708  Product delivery time shuld be fast.Otherwise ...
# 27104       plz allow return policy for all the products
# 27141                                Very very Excellent
# 28193                        nothing every thing is good
# 28808                    Good girl ache se bath ki waaoo
# 28920  Thanku so much for resolving my problem thanks...
# 29365                                         Thank you
# 31681                                         Excellent
# 31697  The lady executive was very polite and I was h...
# 33336                                           Happy ??
# 34544                             THANK YOU Shopzilla ??
# 37420                               Service is very good
# 37501                                         Satishfied
# 37808                                                No
# 38925  Shopzilla should provide all good equipments ....
# 39732                 Great experience in solving issue
# 46703                                              Good
# 46972                    Apse bat karke bahot hi   apka
# 47532                                         Very nice
# 47745                                          It's good
# 48034                                         Excellent
# 48313                                               Good
# 48710           Only one request time is more important
# 49018                                         Excellent
# 55265                                      good services
# 85016  Sir apse muze koi dikkat nhi hai but apka cust...
#
#                                    Order_id   order_date_time  \
# 13565  0258d703-8287-428d-9e48-446e29eec3e5  29/07/2023 03:44
# 13603  d5d704c1-7d8e-4573-8e9d-aec29e6d3b40  31/07/2023 20:21
# 18445  6a318938-1b06-4394-82d7-83a0d7c18f29  29/07/2023 22:52
# 19678  feb6c5f8-5418-4abc-aec4-494ce0df2791    1/8/2023 13:35
# 20080  68b1ae3c-a0f9-48c7-96f0-2e17a460814c    3/8/2023 13:42
# 20363  8f14a636-094a-4810-8d61-c14b2478c9bd  30/07/2023 18:10
# 20439  fe85b0a1-5abb-4f02-8750-61937e039bfd     4/8/2023 0:03
# 22514  9c7ac0e3-2c31-42d6-903e-ad11439ed523    3/8/2023 15:52
# 26301  f89b47a1-c44e-48bd-98d8-037db0ee5d53  21/07/2023 20:12
# 26387  9e94dd00-4e52-4389-91c2-646027ad8680    3/8/2023 11:00
# 26499  6b41d7d0-e746-4a89-b56e-e48704ce111e     5/8/2023 0:40
# 26661  70c121f6-73ee-438c-a8a1-c2debb9f1b30  25/07/2023 14:28
# 26708  a22e098c-72ed-4a12-8348-b9a626361cde    4/8/2023 16:55
# 27104  7c772843-f137-45aa-bbe2-e2d4bf8a1029    3/8/2023 12:05
# 27141  4389d91b-e040-4322-99d8-b9e6549f23b9    7/8/2023 10:47
# 28193  9ee09e99-97a4-4713-8cb1-2d8cf07c41d1    2/8/2023 14:26
# 28808  63f549dd-1f99-4a1d-9be8-4d2de4040cce    3/8/2023 14:30
# 28920  40086ff4-4a4b-4f97-ac50-2aaca7da9571    6/8/2023 16:26
# 29365  8baa3add-355d-491d-8f4c-25ad4f5f4d03    1/8/2023 10:48
# 31681  29313068-1c8e-4253-9ea4-44a5419da215     3/8/2023 9:48
# 31697  155b8e74-98d3-48f8-890e-2b4888905dcd    5/8/2023 12:07
# 33336  a5e11d88-27f0-49c0-adc2-2b9c776d269c     4/8/2023 8:51
# 34544  a5c8d130-0005-4aa1-b3d8-0ce5144ae6c5     8/8/2023 9:03
# 37420  e16cbbea-80e5-4387-a407-2043d70ff80b    3/8/2023 10:46
# 37501  6d9a1662-fb09-4937-b288-6d3cb659d03e    5/8/2023 17:52
# 37808  107f7d8a-6126-4c7b-8680-4fdc1a80fd30    9/8/2023 11:57
# 38925  4660b47e-c6ec-4cf0-9b05-56c9386fe99d    3/8/2023 19:11
# 39732  44f1503a-3f73-44eb-a311-d7584df3b815    7/8/2023 21:29
# 46703  eadb0b0e-4c5c-4105-a458-f0ad7a1f0b1d    9/8/2023 12:45
# 46972  d7dc9ec3-c5e4-4f30-b1fa-54ca1545c4e5    6/8/2023 10:13
# 47532  73cf3e01-19dd-4747-b1da-edb624639e62    4/8/2023 23:05
# 47745  28b67f05-6f59-4d63-a873-d49396a9e87b  13/08/2023 22:07
# 48034  025b5c51-2942-4404-9bfd-27263cb3c829    1/8/2023 21:16
# 48313  0b9e04b3-50d8-473c-bc58-3b0269ed8034    5/8/2023 17:37
# 48710  63e80be2-2f80-4c8c-b516-2166d759f92f    6/8/2023 12:02
# 49018  4f863da4-fd0b-4ad0-ab2f-a7ad93a20157    8/8/2023 21:50
# 55265  297dc352-e97d-4687-b8f6-ba2fa0620488  26/07/2023 14:28
# 85016  3af034d2-a0ac-4693-8d2f-4c21901ef4e1    12/8/2023 6:49
#
#       Issue_reported at   issue_responded Survey_response_Date Customer_City  \
# 13565    5/8/2023 11:11    5/8/2023 11:50             5-Aug-23       BETTIAH
# 13603    4/8/2023 12:04     5/8/2023 7:02             5-Aug-23         PATNA
# 18445    9/8/2023 12:40    9/8/2023 12:43             9-Aug-23          AGRA
# 19678    8/8/2023 12:35    8/8/2023 12:39             8-Aug-23       Birbhum
# 20080    7/8/2023 13:55     8/8/2023 9:21             8-Aug-23      BAREILLY
# 20363    8/8/2023 11:13    8/8/2023 16:01             8-Aug-23         BASTI
# 20439    8/8/2023 11:03    8/8/2023 11:07             8-Aug-23     MADHUGIRI
# 22514    8/8/2023 15:29    8/8/2023 15:32             8-Aug-23     BALESHWAR
# 26301   11/8/2023 19:38   11/8/2023 19:53            11-Aug-23        GOHANA
# 26387   11/8/2023 12:52   11/8/2023 12:56            11-Aug-23    BERHAMPORE
# 26499   11/8/2023 18:20   11/8/2023 19:47            11-Aug-23        MUMBAI
# 26661   12/8/2023 10:40   12/8/2023 10:44            12-Aug-23         ANAND
# 26708   12/8/2023 10:16   12/8/2023 12:17            12-Aug-23       BARASAT
# 27104   11/8/2023 10:26   11/8/2023 10:37            11-Aug-23        MAPUSA
# 27141   11/8/2023 10:06   11/8/2023 10:40            11-Aug-23       BARASAT
# 28193   11/8/2023 11:01   11/8/2023 11:41            11-Aug-23         PATNA
# 28808   11/8/2023 13:09   11/8/2023 13:13            11-Aug-23        BARMER
# 28920   12/8/2023 10:33   12/8/2023 10:53            12-Aug-23         VIRAR
# 29365   11/8/2023 15:21   11/8/2023 17:19            11-Aug-23      VADODARA
# 31681   10/8/2023 12:33   12/8/2023 11:15            12-Aug-23          PURI
# 31697   11/8/2023 10:59   11/8/2023 11:09            11-Aug-23   BHUBANESWAR
# 33336   11/8/2023 20:20   11/8/2023 20:29            11-Aug-23      PANIKOII
# 34544   11/8/2023 10:33   11/8/2023 10:36            11-Aug-23     NEW DELHI
# 37420  14/08/2023 13:35  14/08/2023 14:22            14-Aug-23      MAHESANA
# 37501  14/08/2023 17:42  14/08/2023 17:45            14-Aug-23     NAGERCOIL
# 37808  14/08/2023 18:07  14/08/2023 19:34            14-Aug-23         SALON
# 38925  14/08/2023 13:49  14/08/2023 13:52            14-Aug-23       NALBARI
# 39732  14/08/2023 18:07  14/08/2023 18:10            14-Aug-23       BAGHPAT
# 46703  18/08/2023 19:12  18/08/2023 19:16            18-Aug-23       ROORKEE
# 46972  17/08/2023 15:46  18/08/2023 10:44            18-Aug-23      RAYAGADA
# 47532  18/08/2023 12:33  18/08/2023 12:37            18-Aug-23      NEEMRANA
# 47745  18/08/2023 15:53  18/08/2023 15:58            18-Aug-23      NAMAKKAL
# 48034  18/08/2023 11:01  18/08/2023 11:03            18-Aug-23        MUMBAI
# 48313  18/08/2023 16:28  18/08/2023 16:39            18-Aug-23       KURNOOL
# 48710  18/08/2023 11:48  18/08/2023 11:50            18-Aug-23       DEOGHAR
# 49018  18/08/2023 18:43  18/08/2023 19:00            18-Aug-23     GHAZIABAD
# 55265  19/08/2023 14:11  21/08/2023 14:14            21-Aug-23          MOGA
# 85016  31/08/2023 20:46  31/08/2023 21:17            31-Aug-23      SRINAGAR
#
#       Product_category  Item_price  connected_handling_time  \
# 13565      Electronics       899.0                    367.0
# 13603      Electronics       899.0                    604.0
# 18445      Electronics       868.0                    233.0
# 19678      Electronics       899.0                    458.0
# 20080      Electronics       799.0                    362.0
# 20363      Electronics       699.0                    384.0
# 20439      Electronics       899.0                    655.0
# 22514      Electronics       899.0                    460.0
# 26301      Electronics       899.0                    429.0
# 26387      Electronics       799.0                    217.0
# 26499      Electronics       679.0                    557.0
# 26661      Electronics       899.0                    418.0
# 26708      Electronics       799.0                    466.0
# 27104      Electronics       999.0                    467.0
# 27141      Electronics       799.0                    509.0
# 28193      Electronics       700.0                    253.0
# 28808      Electronics       999.0                    319.0
# 28920      Electronics       999.0                    221.0
# 29365      Electronics       999.0                    454.0
# 31681  Home Appliences       869.0                    368.0
# 31697      Electronics       999.0                    304.0
# 33336      Electronics       999.0                    721.0
# 34544      Electronics       999.0                    265.0
# 37420      Electronics       999.0                    732.0
# 37501  Home Appliences       924.0                    301.0
# 37808      Electronics       899.0                    361.0
# 38925  Home Appliences       999.0                    301.0
# 39732      Electronics       999.0                    398.0
# 46703      Electronics       899.0                     45.0
# 46972      Electronics       775.0                    413.0
# 47532      Electronics       643.0                    227.0
# 47745      Electronics       699.0                    343.0
# 48034      Electronics       899.0                    282.0
# 48313      Electronics       899.0                    299.0
# 48710      Electronics       899.0                    312.0
# 49018      Electronics       899.0                    216.0
# 55265      Electronics       799.0                    364.0
# 85016        LifeStyle       999.0                    505.0
#
#                  Agent_name        Supervisor          Manager  \
# 13565        Katelyn Horton       Mason Gupta       Olivia Tan
# 13603          Michael Ruiz       Madison Kim       John Smith
# 18445         Dillon Miller       Mason Gupta       Olivia Tan
# 19678         Dillon Miller       Mason Gupta       Olivia Tan
# 20080        Patricia Cross       Mason Gupta       Olivia Tan
# 20363           Daniel Ball    Ethan Nakamura       Olivia Tan
# 20439       Evelyn Petersen       Olivia Wang       Olivia Tan
# 22514  Christopher Anderson       Mason Gupta       Olivia Tan
# 26301        Patricia Cross       Mason Gupta       Olivia Tan
# 26387        Michael Dunlap  Charlotte Suzuki  Jennifer Nguyen
# 26499          Mary Vasquez       Olivia Wang       Olivia Tan
# 26661          Teresa Nolan          Ava Wong       Olivia Tan
# 26708     Kathleen Williams       Mason Gupta       Olivia Tan
# 27104          Devon Daniel       Olivia Wang       Olivia Tan
# 27141          Mary Vasquez       Olivia Wang       Olivia Tan
# 28193           Tammy Rojas         Mia Patel       Olivia Tan
# 28808         Tammy Cochran       Madison Kim       John Smith
# 28920           James Chung     Oliver Nguyen       John Smith
# 29365          Edward Perez       Olivia Wang       Olivia Tan
# 31681         Erik Williams         Mia Patel       Olivia Tan
# 31697          Edward Perez       Olivia Wang       Olivia Tan
# 33336        Timothy Bailey       Mason Gupta       Olivia Tan
# 34544        Michael Dunlap  Charlotte Suzuki  Jennifer Nguyen
# 37420              Sean Gay         Mia Patel       Olivia Tan
# 37501        Jennifer Perry         Mia Patel       Olivia Tan
# 37808    Nicole Simpson DVM       Mason Gupta       Olivia Tan
# 38925        Timothy Bailey       Mason Gupta       Olivia Tan
# 39732     Kathleen Williams       Mason Gupta       Olivia Tan
# 46703       Jessica Mcbride       Olivia Wang       Olivia Tan
# 46972             Bob Keith         Mia Patel       Olivia Tan
# 47532        Timothy Bailey       Mason Gupta       Olivia Tan
# 47745    Nicole Simpson DVM       Mason Gupta       Olivia Tan
# 48034        Jennifer Perry         Mia Patel       Olivia Tan
# 48313           Tammy Rojas         Mia Patel       Olivia Tan
# 48710           Tammy Rojas         Mia Patel       Olivia Tan
# 49018        Jennifer Perry         Mia Patel       Olivia Tan
# 55265        Jennifer Perry         Mia Patel       Olivia Tan
# 85016            John Jones       Aiden Patel       John Smith
#
#          Tenure Bucket Agent Shift  CSAT Score
# 13565             0-30     Morning           5
# 13603              >90     Morning           2
# 18445             0-30     Morning           4
# 19678             0-30     Morning           5
# 20080             0-30   Afternoon           5
# 20363              >90     Morning           5
# 20439             0-30     Morning           5
# 22514             0-30   Afternoon           5
# 26301             0-30   Afternoon           4
# 26387  On Job Training     Evening           5
# 26499             0-30     Morning           5
# 26661              >90     Morning           5
# 26708              >90     Morning           5
# 27104             0-30   Afternoon           5
# 27141             0-30     Morning           5
# 28193              >90     Morning           5
# 28808              >90       Split           5
# 28920              >90     Morning           5
# 29365              >90     Morning           4
# 31681              >90     Morning           5
# 31697              >90     Morning           5
# 33336              >90   Afternoon           5
# 34544  On Job Training     Evening           5
# 37420              >90     Morning           5
# 37501              >90     Morning           4
# 37808              >90     Morning           5
# 38925              >90   Afternoon           5
# 39732              >90     Morning           5
# 46703             0-30   Afternoon           5
# 46972             0-30   Afternoon           5
# 47532              >90   Afternoon           5
# 47745              >90     Morning           5
# 48034              >90     Morning           1
# 48313              >90     Morning           3
# 48710              >90     Morning           4
# 49018              >90     Morning           5
# 55265              >90     Morning           4
# 85016              >90     Morning           4

# %%
#saved cleaned file
df=df.to_csv("c:/labmentix/5th project/clean_data1.csv", index=False)
df

# %%
#import cleaned file
df=pd.read_csv("c:/labmentix/5th project/clean_data1.csv")
df
# Out:
#                                Unique id channel_name       category  \
# 0   08c6a929-a403-4f14-810f-2275fe591230      Outcall        Returns
# 1   eae37bb3-91ec-4154-ba3c-7e4a6309a946      Outcall        Returns
# 2   296c5c93-6a4f-4fa5-b276-3feecfeaf636      Outcall        Returns
# 3   5155d369-7bc3-4c40-9e26-6dcee58ace99      Outcall        Returns
# 4   ddaae943-3535-452e-857f-591d4b9ae0c8      Outcall   Cancellation
# 5   00c52c83-d40a-4b0f-80ea-fcffe23cef76      Outcall        Returns
# 6   5b3a9dfe-8c26-4c5f-9824-02db5daf7ecb      Outcall        Returns
# 7   8d093faf-8359-494d-9955-224cf8a5de8d      Outcall        Returns
# 8   150a36e8-48bc-47d2-bce6-436b65d2fab8      Outcall        Returns
# 9   1c0c98aa-2fdc-4899-af96-de7cbec1977c      Outcall        Returns
# 10  43efcc9f-7143-4895-8ffe-e50421ee8b00      Outcall        Returns
# 11  891fd7e5-59a5-43f9-9b1c-cf9b2e14b14e      Outcall        Returns
# 12  82d615a4-6731-4a79-84b7-2bdb42e2c4dc      Outcall        Returns
# 13  821583b1-48d9-40bb-849c-a32b0382d1fc      Outcall        Returns
# 14  b4c7ceea-92d5-4f75-81aa-4e0a129ee638      Outcall        Returns
# 15  22df64f7-2530-46e1-ba58-fee4265802f5      Outcall        Returns
# 16  bc34a27a-bf19-4132-9629-88b09a9b6e2a      Outcall        Returns
# 17  75bc0360-b5c6-4566-9880-24d5681f2de6      Outcall        Returns
# 18  07030f1f-84c9-493c-a8a3-159f6d58ebc9      Outcall   Cancellation
# 19  f5b74aa2-934d-4d44-a9aa-db68f42fc1c3      Outcall        Returns
# 20  b9d109b9-35fa-40b2-a358-8ef83ac47bda      Outcall   Cancellation
# 21  abf385db-925e-44c5-8112-a4399b61716c      Outcall        Returns
# 22  7f55a2c1-9e16-4dd4-aa1c-8c28b40e02e0      Outcall   Cancellation
# 23  28c46a62-2be4-401b-b73c-2c68486dd5cc      Outcall        Returns
# 24  ee67e456-4cc1-40a4-9253-d1ecca814030      Outcall        Returns
# 25  27c2659e-df10-4bac-af87-da3fae75a8b2      Outcall        Returns
# 26  f5b9f8d9-05d1-4e67-b5dd-01b37b0a71b6      Outcall        Returns
# 27  473de3fb-934b-4dd4-8f9d-91559ce291a8      Outcall        Returns
# 28  ce3a498d-727a-4378-9b2f-519fb1e85c12      Outcall        Returns
# 29  98105df6-15f2-4e73-a593-38138e4fdee4      Outcall        Returns
# 30  66b067d8-cbb0-4d92-ad94-9b9fc760e269      Outcall        Returns
# 31  89b8ba13-fa38-4ed9-8c67-b0ee610cac30      Outcall        Returns
# 32  7905b6ac-e5c0-45e5-a71c-989d6050ceef      Outcall        Returns
# 33  94e83ff7-d920-4b6c-a590-afadb71f85e4      Outcall        Returns
# 34  f9af8085-e991-4205-8804-caefe6194040      Outcall        Returns
# 35  b6501670-1fcc-49cb-8ab6-95fd411fc851      Outcall        Returns
# 36  d1a52873-389a-4ad3-8043-7480181bda2a      Outcall        Returns
# 37  2adb7651-c900-43b9-a539-d8f1d64df3c5      Inbound  Order Related
#
#             Sub-category                                   Customer Remarks  \
# 0         Return request                                               Good
# 1         Return request                                          Not good
# 2         Return request                                  Call was helpful.
# 3         Return request                                       Good service
# 4    Return cancellation                                            Thanks
# 5         Return request                                           Good job
# 6         Return request                                Super customer care
# 7         Return request                         Very genuine person ??????
# 8         Return request  Product is not best.delivery good.costmor care...
# 9         Return request                              Shopzilla Is the Best
# 10        Return request                                               Good
# 11        Return request                                          Thankyou
# 12        Return request  Product delivery time shuld be fast.Otherwise ...
# 13        Return request       plz allow return policy for all the products
# 14        Return request                                Very very Excellent
# 15        Return request                        nothing every thing is good
# 16        Return request                    Good girl ache se bath ki waaoo
# 17        Return request  Thanku so much for resolving my problem thanks...
# 18   Return cancellation                                         Thank you
# 19        Return request                                         Excellent
# 20   Return cancellation  The lady executive was very polite and I was h...
# 21        Return request                                           Happy ??
# 22   Return cancellation                             THANK YOU Shopzilla ??
# 23        Return request                               Service is very good
# 24        Return request                                         Satishfied
# 25        Return request                                                No
# 26        Return request  Shopzilla should provide all good equipments ....
# 27        Return request                 Great experience in solving issue
# 28        Return request                                              Good
# 29        Return request                    Apse bat karke bahot hi   apka
# 30        Return request                                         Very nice
# 31        Return request                                          It's good
# 32        Return request                                         Excellent
# 33        Return request                                               Good
# 34        Return request           Only one request time is more important
# 35        Return request                                         Excellent
# 36        Return request                                      good services
# 37  Order status enquiry  Sir apse muze koi dikkat nhi hai but apka cust...
#
#                                 Order_id   order_date_time Issue_reported at  \
# 0   0258d703-8287-428d-9e48-446e29eec3e5  29/07/2023 03:44    5/8/2023 11:11
# 1   d5d704c1-7d8e-4573-8e9d-aec29e6d3b40  31/07/2023 20:21    4/8/2023 12:04
# 2   6a318938-1b06-4394-82d7-83a0d7c18f29  29/07/2023 22:52    9/8/2023 12:40
# 3   feb6c5f8-5418-4abc-aec4-494ce0df2791    1/8/2023 13:35    8/8/2023 12:35
# 4   68b1ae3c-a0f9-48c7-96f0-2e17a460814c    3/8/2023 13:42    7/8/2023 13:55
# 5   8f14a636-094a-4810-8d61-c14b2478c9bd  30/07/2023 18:10    8/8/2023 11:13
# 6   fe85b0a1-5abb-4f02-8750-61937e039bfd     4/8/2023 0:03    8/8/2023 11:03
# 7   9c7ac0e3-2c31-42d6-903e-ad11439ed523    3/8/2023 15:52    8/8/2023 15:29
# 8   f89b47a1-c44e-48bd-98d8-037db0ee5d53  21/07/2023 20:12   11/8/2023 19:38
# 9   9e94dd00-4e52-4389-91c2-646027ad8680    3/8/2023 11:00   11/8/2023 12:52
# 10  6b41d7d0-e746-4a89-b56e-e48704ce111e     5/8/2023 0:40   11/8/2023 18:20
# 11  70c121f6-73ee-438c-a8a1-c2debb9f1b30  25/07/2023 14:28   12/8/2023 10:40
# 12  a22e098c-72ed-4a12-8348-b9a626361cde    4/8/2023 16:55   12/8/2023 10:16
# 13  7c772843-f137-45aa-bbe2-e2d4bf8a1029    3/8/2023 12:05   11/8/2023 10:26
# 14  4389d91b-e040-4322-99d8-b9e6549f23b9    7/8/2023 10:47   11/8/2023 10:06
# 15  9ee09e99-97a4-4713-8cb1-2d8cf07c41d1    2/8/2023 14:26   11/8/2023 11:01
# 16  63f549dd-1f99-4a1d-9be8-4d2de4040cce    3/8/2023 14:30   11/8/2023 13:09
# 17  40086ff4-4a4b-4f97-ac50-2aaca7da9571    6/8/2023 16:26   12/8/2023 10:33
# 18  8baa3add-355d-491d-8f4c-25ad4f5f4d03    1/8/2023 10:48   11/8/2023 15:21
# 19  29313068-1c8e-4253-9ea4-44a5419da215     3/8/2023 9:48   10/8/2023 12:33
# 20  155b8e74-98d3-48f8-890e-2b4888905dcd    5/8/2023 12:07   11/8/2023 10:59
# 21  a5e11d88-27f0-49c0-adc2-2b9c776d269c     4/8/2023 8:51   11/8/2023 20:20
# 22  a5c8d130-0005-4aa1-b3d8-0ce5144ae6c5     8/8/2023 9:03   11/8/2023 10:33
# 23  e16cbbea-80e5-4387-a407-2043d70ff80b    3/8/2023 10:46  14/08/2023 13:35
# 24  6d9a1662-fb09-4937-b288-6d3cb659d03e    5/8/2023 17:52  14/08/2023 17:42
# 25  107f7d8a-6126-4c7b-8680-4fdc1a80fd30    9/8/2023 11:57  14/08/2023 18:07
# 26  4660b47e-c6ec-4cf0-9b05-56c9386fe99d    3/8/2023 19:11  14/08/2023 13:49
# 27  44f1503a-3f73-44eb-a311-d7584df3b815    7/8/2023 21:29  14/08/2023 18:07
# 28  eadb0b0e-4c5c-4105-a458-f0ad7a1f0b1d    9/8/2023 12:45  18/08/2023 19:12
# 29  d7dc9ec3-c5e4-4f30-b1fa-54ca1545c4e5    6/8/2023 10:13  17/08/2023 15:46
# 30  73cf3e01-19dd-4747-b1da-edb624639e62    4/8/2023 23:05  18/08/2023 12:33
# 31  28b67f05-6f59-4d63-a873-d49396a9e87b  13/08/2023 22:07  18/08/2023 15:53
# 32  025b5c51-2942-4404-9bfd-27263cb3c829    1/8/2023 21:16  18/08/2023 11:01
# 33  0b9e04b3-50d8-473c-bc58-3b0269ed8034    5/8/2023 17:37  18/08/2023 16:28
# 34  63e80be2-2f80-4c8c-b516-2166d759f92f    6/8/2023 12:02  18/08/2023 11:48
# 35  4f863da4-fd0b-4ad0-ab2f-a7ad93a20157    8/8/2023 21:50  18/08/2023 18:43
# 36  297dc352-e97d-4687-b8f6-ba2fa0620488  26/07/2023 14:28  19/08/2023 14:11
# 37  3af034d2-a0ac-4693-8d2f-4c21901ef4e1    12/8/2023 6:49  31/08/2023 20:46
#
#      issue_responded Survey_response_Date Customer_City Product_category  \
# 0     5/8/2023 11:50             5-Aug-23       BETTIAH      Electronics
# 1      5/8/2023 7:02             5-Aug-23         PATNA      Electronics
# 2     9/8/2023 12:43             9-Aug-23          AGRA      Electronics
# 3     8/8/2023 12:39             8-Aug-23       Birbhum      Electronics
# 4      8/8/2023 9:21             8-Aug-23      BAREILLY      Electronics
# 5     8/8/2023 16:01             8-Aug-23         BASTI      Electronics
# 6     8/8/2023 11:07             8-Aug-23     MADHUGIRI      Electronics
# 7     8/8/2023 15:32             8-Aug-23     BALESHWAR      Electronics
# 8    11/8/2023 19:53            11-Aug-23        GOHANA      Electronics
# 9    11/8/2023 12:56            11-Aug-23    BERHAMPORE      Electronics
# 10   11/8/2023 19:47            11-Aug-23        MUMBAI      Electronics
# 11   12/8/2023 10:44            12-Aug-23         ANAND      Electronics
# 12   12/8/2023 12:17            12-Aug-23       BARASAT      Electronics
# 13   11/8/2023 10:37            11-Aug-23        MAPUSA      Electronics
# 14   11/8/2023 10:40            11-Aug-23       BARASAT      Electronics
# 15   11/8/2023 11:41            11-Aug-23         PATNA      Electronics
# 16   11/8/2023 13:13            11-Aug-23        BARMER      Electronics
# 17   12/8/2023 10:53            12-Aug-23         VIRAR      Electronics
# 18   11/8/2023 17:19            11-Aug-23      VADODARA      Electronics
# 19   12/8/2023 11:15            12-Aug-23          PURI  Home Appliences
# 20   11/8/2023 11:09            11-Aug-23   BHUBANESWAR      Electronics
# 21   11/8/2023 20:29            11-Aug-23      PANIKOII      Electronics
# 22   11/8/2023 10:36            11-Aug-23     NEW DELHI      Electronics
# 23  14/08/2023 14:22            14-Aug-23      MAHESANA      Electronics
# 24  14/08/2023 17:45            14-Aug-23     NAGERCOIL  Home Appliences
# 25  14/08/2023 19:34            14-Aug-23         SALON      Electronics
# 26  14/08/2023 13:52            14-Aug-23       NALBARI  Home Appliences
# 27  14/08/2023 18:10            14-Aug-23       BAGHPAT      Electronics
# 28  18/08/2023 19:16            18-Aug-23       ROORKEE      Electronics
# 29  18/08/2023 10:44            18-Aug-23      RAYAGADA      Electronics
# 30  18/08/2023 12:37            18-Aug-23      NEEMRANA      Electronics
# 31  18/08/2023 15:58            18-Aug-23      NAMAKKAL      Electronics
# 32  18/08/2023 11:03            18-Aug-23        MUMBAI      Electronics
# 33  18/08/2023 16:39            18-Aug-23       KURNOOL      Electronics
# 34  18/08/2023 11:50            18-Aug-23       DEOGHAR      Electronics
# 35  18/08/2023 19:00            18-Aug-23     GHAZIABAD      Electronics
# 36  21/08/2023 14:14            21-Aug-23          MOGA      Electronics
# 37  31/08/2023 21:17            31-Aug-23      SRINAGAR        LifeStyle
#
#     Item_price  connected_handling_time            Agent_name  \
# 0        899.0                    367.0        Katelyn Horton
# 1        899.0                    604.0          Michael Ruiz
# 2        868.0                    233.0         Dillon Miller
# 3        899.0                    458.0         Dillon Miller
# 4        799.0                    362.0        Patricia Cross
# 5        699.0                    384.0           Daniel Ball
# 6        899.0                    655.0       Evelyn Petersen
# 7        899.0                    460.0  Christopher Anderson
# 8        899.0                    429.0        Patricia Cross
# 9        799.0                    217.0        Michael Dunlap
# 10       679.0                    557.0          Mary Vasquez
# 11       899.0                    418.0          Teresa Nolan
# 12       799.0                    466.0     Kathleen Williams
# 13       999.0                    467.0          Devon Daniel
# 14       799.0                    509.0          Mary Vasquez
# 15       700.0                    253.0           Tammy Rojas
# 16       999.0                    319.0         Tammy Cochran
# 17       999.0                    221.0           James Chung
# 18       999.0                    454.0          Edward Perez
# 19       869.0                    368.0         Erik Williams
# 20       999.0                    304.0          Edward Perez
# 21       999.0                    721.0        Timothy Bailey
# 22       999.0                    265.0        Michael Dunlap
# 23       999.0                    732.0              Sean Gay
# 24       924.0                    301.0        Jennifer Perry
# 25       899.0                    361.0    Nicole Simpson DVM
# 26       999.0                    301.0        Timothy Bailey
# 27       999.0                    398.0     Kathleen Williams
# 28       899.0                     45.0       Jessica Mcbride
# 29       775.0                    413.0             Bob Keith
# 30       643.0                    227.0        Timothy Bailey
# 31       699.0                    343.0    Nicole Simpson DVM
# 32       899.0                    282.0        Jennifer Perry
# 33       899.0                    299.0           Tammy Rojas
# 34       899.0                    312.0           Tammy Rojas
# 35       899.0                    216.0        Jennifer Perry
# 36       799.0                    364.0        Jennifer Perry
# 37       999.0                    505.0            John Jones
#
#           Supervisor          Manager    Tenure Bucket Agent Shift  CSAT Score
# 0        Mason Gupta       Olivia Tan             0-30     Morning           5
# 1        Madison Kim       John Smith              >90     Morning           2
# 2        Mason Gupta       Olivia Tan             0-30     Morning           4
# 3        Mason Gupta       Olivia Tan             0-30     Morning           5
# 4        Mason Gupta       Olivia Tan             0-30   Afternoon           5
# 5     Ethan Nakamura       Olivia Tan              >90     Morning           5
# 6        Olivia Wang       Olivia Tan             0-30     Morning           5
# 7        Mason Gupta       Olivia Tan             0-30   Afternoon           5
# 8        Mason Gupta       Olivia Tan             0-30   Afternoon           4
# 9   Charlotte Suzuki  Jennifer Nguyen  On Job Training     Evening           5
# 10       Olivia Wang       Olivia Tan             0-30     Morning           5
# 11          Ava Wong       Olivia Tan              >90     Morning           5
# 12       Mason Gupta       Olivia Tan              >90     Morning           5
# 13       Olivia Wang       Olivia Tan             0-30   Afternoon           5
# 14       Olivia Wang       Olivia Tan             0-30     Morning           5
# 15         Mia Patel       Olivia Tan              >90     Morning           5
# 16       Madison Kim       John Smith              >90       Split           5
# 17     Oliver Nguyen       John Smith              >90     Morning           5
# 18       Olivia Wang       Olivia Tan              >90     Morning           4
# 19         Mia Patel       Olivia Tan              >90     Morning           5
# 20       Olivia Wang       Olivia Tan              >90     Morning           5
# 21       Mason Gupta       Olivia Tan              >90   Afternoon           5
# 22  Charlotte Suzuki  Jennifer Nguyen  On Job Training     Evening           5
# 23         Mia Patel       Olivia Tan              >90     Morning           5
# 24         Mia Patel       Olivia Tan              >90     Morning           4
# 25       Mason Gupta       Olivia Tan              >90     Morning           5
# 26       Mason Gupta       Olivia Tan              >90   Afternoon           5
# 27       Mason Gupta       Olivia Tan              >90     Morning           5
# 28       Olivia Wang       Olivia Tan             0-30   Afternoon           5
# 29         Mia Patel       Olivia Tan             0-30   Afternoon           5
# 30       Mason Gupta       Olivia Tan              >90   Afternoon           5
# 31       Mason Gupta       Olivia Tan              >90     Morning           5
# 32         Mia Patel       Olivia Tan              >90     Morning           1
# 33         Mia Patel       Olivia Tan              >90     Morning           3
# 34         Mia Patel       Olivia Tan              >90     Morning           4
# 35         Mia Patel       Olivia Tan              >90     Morning           5
# 36         Mia Patel       Olivia Tan              >90     Morning           4
# 37       Aiden Patel       John Smith              >90     Morning           4

# %%
# Path to your file (as uploaded)
CSV_PATH = "C:/labmentix/5th project/clean_data1.csv"

# ------------- Utilities: load and inspect ----------------
def load_inspect(csv_path):
    print("Loading:", csv_path)
    df = pd.read_csv(csv_path)
    print("Shape:", df.shape)
    display_cols = list(df.columns[:30])
    print("Columns (first 30):", display_cols)
    print("\nSample rows:")
    print(df.head(3).T)
    print("\nColumn dtypes and missingness:")
    print(pd.DataFrame({'dtype': df.dtypes, 'missing': df.isna().mean()}).sort_values('missing', ascending=False).head(50))
    return df
    
df = load_inspect(CSV_PATH)

# ------------- Auto-detect label and feature types -------------
# Heuristic: look for csat, satisfaction, rating, score
label_candidates = [c for c in df.columns if 'csat' in c.lower() or 'satisf' in c.lower() or 'rating' in c.lower() or 'score' in c.lower()]
if len(label_candidates) == 0:
    raise ValueError("No label column found automatically. Please rename your CSAT column to include 'csat' or 'satisfaction' or 'rating' or 'score'. Columns found: " + ", ".join(df.columns))
label_col = label_candidates[0]
print("Using label column:", label_col)

# Identify text columns heuristically
text_cols = [c for c in df.columns if df[c].dtype == object and df[c].nunique() > 20]  # non-trivial textual columns
# remove likely id columns
id_like = [c for c in df.columns if 'id' in c.lower()]
text_cols = [c for c in text_cols if c not in id_like and c != label_col]
print("Detected potential text columns:", text_cols)

# Numeric and categorical features
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Remove label from numeric list
if label_col in num_cols:
    num_cols.remove(label_col)
cat_cols = [c for c in df.columns if c not in num_cols and c not in text_cols and c != label_col]

# remove id-like and timestamp-like
cat_cols = [c for c in cat_cols if 'id' not in c.lower() and 'time' not in c.lower() and 'date' not in c.lower()]

print("Numeric columns:", num_cols)
print("Categorical columns:", cat_cols)

# ------------- Simple feature engineering -------------
# Example derived features depending on availability
if 'order_value' in df.columns and 'delivery_time' in df.columns:
    df['value_per_hour'] = df['order_value'] / (df['delivery_time'] + 1e-6)
    num_cols.append('value_per_hour')

# Fill missing basics now (we'll build pipelines later too)
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
for c in cat_cols:
    df[c] = df[c].fillna('MISSING')

# ------------- Split ----------------
X_all = df.drop(columns=[label_col])
y_all = df[label_col].astype(float)

X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2, random_state=42)
print("Train/Test split:", X_train.shape, X_test.shape)

# ------------- Baseline: XGBoost on tabular (and TF-IDF if text present) -------------
# Build preprocessing for tabular
numeric_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
# For categorical, do simple label encoding per column using mapping saved (since OneHot can explode)
def label_encode_df(df_train, df_valid, cat_columns):
    encoders = {}
    for col in cat_columns:
        le = LabelEncoder()
        le.fit(list(df_train[col].astype(str).values) + list(df_valid[col].astype(str).values))
        encoders[col] = le
        df_train[col] = le.transform(df_train[col].astype(str).values)
        df_valid[col] = le.transform(df_valid[col].astype(str).values)
    return df_train, df_valid, encoders

# For text, build TF-IDF features (top 500 features)
use_text = len(text_cols) > 0
tfidf = None
if use_text:
     # combine all text columns into a single column for simplicity
    TEXT_FIELD = "combined_review_text"
    X_train[TEXT_FIELD] = X_train[text_cols].fillna("").agg(" ".join, axis=1)
    X_test[TEXT_FIELD] = X_test[text_cols].fillna("").agg(" ".join, axis=1)
    tfidf = TfidfVectorizer(max_features=500, ngram_range=(1,2))
    tfidf.fit(pd.concat([X_train[TEXT_FIELD], X_test[TEXT_FIELD]]))
    X_train_tfidf = tfidf.transform(X_train[TEXT_FIELD]).toarray()
    X_test_tfidf = tfidf.transform(X_test[TEXT_FIELD]).toarray()
    print("TF-IDF shape:", X_train_tfidf.shape)

# Encode categorical cols
X_train_enc = X_train.copy()
X_test_enc = X_test.copy()
X_train_enc, X_test_enc, encoders = label_encode_df(X_train_enc, X_test_enc, cat_cols)

# Scale numeric columns
scaler = StandardScaler()
X_train_num = scaler.fit_transform(X_train_enc[num_cols])
X_test_num = scaler.transform(X_test_enc[num_cols])

# Build final tabular matrix
if use_text:
    X_train_tab = np.hstack([X_train_num, X_train_enc[cat_cols].values, X_train_tfidf])
    X_test_tab = np.hstack([X_test_num, X_test_enc[cat_cols].values, X_test_tfidf])
else:
    X_train_tab = np.hstack([X_train_num, X_train_enc[cat_cols].values])
    X_test_tab = np.hstack([X_test_num, X_test_enc[cat_cols].values])

print("Tabular matrix shapes:", X_train_tab.shape, X_test_tab.shape)

# Train XGBoost regressor
xgb_model = xgb.XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=6, subsample=0.8, colsample_bytree=0.8, random_state=42)
xgb_model.fit(X_train_tab, y_train, eval_set=[(X_test_tab, y_test)], verbose=50)

# Evaluate baseline
pred_xgb = xgb_model.predict(X_test_tab)
def to_numpy(y):
    """Convert pandas Series / list to numpy 1d float array."""
    if hasattr(y, "to_numpy"):
        arr = y.to_numpy()
    else:
        arr = np.array(y)
    # flatten and convert to float
    arr = np.asarray(arr).astype(float).ravel()
    return arr
    
def print_metrics(y_true, y_pred, prefix=""):
    """
    Print MAE, RMSE and R2 in a version-safe way.
    Handles pandas Series and numpy arrays.
    """
    y_true = to_numpy(y_true)
    y_pred = to_numpy(y_pred)

    # ensure same length
    if y_true.shape[0] != y_pred.shape[0]:
        raise ValueError(f"y_true and y_pred length mismatch: {y_true.shape[0]} vs {y_pred.shape[0]}")

    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)   # returns MSE
    rmse = np.sqrt(mse)                        # version-safe RMSE
    r2 = r2_score(y_true, y_pred)

    print(f"{prefix} MAE: {mae:.4f}  RMSE: {rmse:.4f}  R2: {r2:.4f}")

print_metrics(y_test, pred_xgb, prefix="XGBoost Baseline")

# Save baseline artifacts
joblib.dump(scaler, "deepcsat_scaler.joblib")
joblib.dump(encoders, "deepcsat_cat_encoders.joblib")
if use_text: joblib.dump(tfidf, "deepcsat_tfidf.joblib")
xgb_model.save_model("deepcsat_xgb.json")

# ------------- SHAP explainability for baseline -------------
print("Computing SHAP values (TreeExplainer) — this may take a few minutes...")

# Ensure input is numpy array (SHAP needs array-like)
X_sample = np.array(X_test_tab[:500])   # use a sample for speed

# Use TreeExplainer (explicit for XGBoost)
# after training xgb_model
booster = xgb_model.get_booster()
booster.save_model("deepcsat_xgb.bin")      # binary model, not JSON
xgb_model = xgb.XGBRegressor()
xgb_model.load_model("deepcsat_xgb.bin")    # reload it

# Plot SHAP summary
plt.title("SHAP Feature Importance (Top Features)")
shap.summary_plot(shap_values, features, feature_names=None, max_display=20)

# ------------- Multimodal deep model (tabular + text) -------------
# We'll build a Keras model that takes tabular numeric+cat features and TF-IDF text vector (dense) or a text embedding

def build_deep_model(tab_input_dim, text_input_dim=None):
    # Tabular branch
    tab_in = layers.Input(shape=(tab_input_dim,), name="tab_input")
    x = layers.Dense(128, activation='relu')(tab_in)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(64, activation='relu')(x)
    tab_out = layers.Dense(32, activation='relu')(x)

    if text_input_dim is not None:
        text_in = layers.Input(shape=(text_input_dim,), name="text_input")
        t = layers.Dense(128, activation='relu')(text_in)
        t = layers.Dropout(0.2)(t)
        t = layers.Dense(64, activation='relu')(t)
        text_out = layers.Dense(32, activation='relu')(t)
        merged = layers.concatenate([tab_out, text_out])
        input_list = [tab_in, text_in]
    else:
        merged = tab_out
        input_list = [tab_in]
    y = layers.Dense(64, activation='relu')(merged)
    y = layers.Dropout(0.2)(y)
    y = layers.Dense(32, activation='relu')(y)
    out = layers.Dense(1, activation='linear')(y)  # regression

    model = models.Model(inputs=input_list, outputs=out)
    model.compile(optimizer=optimizers.Adam(learning_rate=1e-3), loss='mse', metrics=['mae'])
    return model

# For deep model, we'll use same tabular numeric+cat features (no TF-IDF expansion to keep dims reasonable)
# We already combined num + categorical indices into arrays; let's form a compact tab input
tab_train = np.hstack([X_train_num, X_train_enc[cat_cols].values])
tab_test = np.hstack([X_test_num, X_test_enc[cat_cols].values])
if use_text:
    # Option A: Use TF-IDF dense (already computed) — can be high-dim
    text_train = X_train_tfidf
    text_test = X_test_tfidf
    deep_model = build_deep_model(tab_train.shape[1], text_train.shape[1])
    history = deep_model.fit([tab_train, text_train], y_train, validation_data=([tab_test, text_test], y_test),
                             epochs=50, batch_size=64, callbacks=[callbacks.EarlyStopping(patience=6, restore_best_weights=True)])
else:
    deep_model = build_deep_model(tab_train.shape[1], text_input_dim=None)
    history = deep_model.fit(tab_train, y_train, validation_data=(tab_test, y_test),
                             epochs=50, batch_size=64, callbacks=[callbacks.EarlyStopping(patience=6, restore_best_weights=True)])
# Evaluate deep model
if use_text:
    pred_deep = deep_model.predict([tab_test, text_test]).flatten()
else:
    pred_deep = deep_model.predict(tab_test).flatten()

print_metrics(y_test, pred_deep, prefix="Deep Model")

# Plot loss curves
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Deep Model Training Loss'); plt.xlabel('Epoch'); plt.show()

# Save deep model
deep_model.save("deepcsat_deep_model.h5")
joblib.dump({'num_cols': num_cols, 'cat_cols': cat_cols, 'text_cols': text_cols, 'label_col': label_col}, "deepcsat_metadata.joblib")

# ------------- Analysis: predictions vs actual and group analysis -------------
res = X_test.copy()
res['actual'] = y_test
res['xgb_pred'] = pred_xgb
res['deep_pred'] = pred_deep
res['xgb_err'] = np.abs(res['actual'] - res['xgb_pred'])
res['deep_err'] = np.abs(res['actual'] - res['deep_pred'])

print("Overall MAE (XGB):", mean_absolute_error(res['actual'], res['xgb_pred']))
print("Overall MAE (Deep):", mean_absolute_error(res['actual'], res['deep_pred']))

# Error by category if product_category exists
if 'product_category' in res.columns:
    cat_summary = res.groupby('product_category')[['actual', 'xgb_pred', 'deep_pred']].mean()
    print(cat_summary.sort_values('actual').head())
    
# Save results to CSV for review
res.to_csv("deepcsat_test_results.csv", index=False)

# ------------- Quick local Flask server for predictions -------------
# Save final artifacts for serving: scaler, encoders, tfidf, deep model file already saved.
print("Artifacts saved: deepcsat_deep_model.h5, deepcsat_xgb.json, deepcsat_scaler.joblib, deepcsat_cat_encoders.joblib")
print("You can now run a Flask app (example below) to serve predictions.")

# %%
# serve_deepcsat.py
from flask import Flask, request, jsonify
import joblib
import numpy as np
import tensorflow as tf
import xgboost as xgb
import json

app = Flask(__name__)

# Load artifacts
scaler = joblib.load("deepcsat_scaler.joblib")
encoders = joblib.load("deepcsat_cat_encoders.joblib")
meta = joblib.load("deepcsat_metadata.joblib")
use_text = False
try:
    tfidf = joblib.load("deepcsat_tfidf.joblib")
    use_text = True
except:
    tfidf = None
    
xgb_model = xgb.XGBRegressor()
xgb_model.load_model("deepcsat_xgb.json")
deep_model = tf.keras.models.load_model("deepcsat_deep_model.h5")

num_cols = meta['num_cols']
cat_cols = meta['cat_cols']
text_cols = meta['text_cols']

def preprocess_single(record):
    # record: dict of feature_name -> value
    # Build DataFrame-like row processing
    import pandas as pd
    row = {}
    for c in num_cols:
        row[c] = float(record.get(c, 0.0))
    for c in cat_cols:
        row[c] = str(record.get(c, 'MISSING'))
    df_row = pd.DataFrame([row])
    # Encode categorical
    for c in cat_cols:
        le = encoders[c]
        # if unseen categories: map to existing via try/except
        val = df_row.at[0,c]
        if val in le.classes_:
            df_row[c] = le.transform([val])[0]
        else:
            # add to classes temporarily (map to -1 or nearest)
            df_row[c] = 0
    # scale numeric
    X_num = scaler.transform(df_row[num_cols])
    X_tab = np.hstack([X_num, df_row[cat_cols].values])
    if use_text and text_cols:
        combined_text = " ".join([str(record.get(c, "")) for c in text_cols])
        text_vec = tfidf.transform([combined_text]).toarray()
        return X_tab, text_vec
    return X_tab, None

@app.route('/predict', methods=['POST'])
def predict():
    payload = request.json
    X_tab, text_vec = preprocess_single(payload)
    # XGBoost
    xgb_pred = xgb_model.predict(np.hstack([X_tab, text_vec]) if text_vec is not None else X_tab)[0]
    # Deep
    if text_vec is not None:
        deep_pred = deep_model.predict([X_tab, text_vec])[0][0]
    else:
        deep_pred = deep_model.predict(X_tab)[0][0]
    return jsonify({'xgb_pred': float(xgb_pred), 'deep_pred': float(deep_pred)})

if __name__ == '__main__':
    app.run(port=5000, debug=False)
